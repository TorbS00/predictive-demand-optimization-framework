# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../data/historical_data.csv')

df.head()
# Out:
#          Date   Price  Demand
# 0  2021-01-01  143.64   113.0
# 1  2021-01-02  287.68    97.0
# 2  2021-01-03  233.00    85.0
# 3  2021-01-04  199.66   106.0
# 4  2021-01-05   89.00   127.0

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='Date', y='Demand')
plt.title('Demand Trends Over Time')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='Date', y='Demand')
plt.title('Demand Trends Over Time')
# Out:
# Text(0.5, 1.0, 'Demand Trends Over Time')

# %%
import matplotlib.dates as mdates

plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# %%
plt.gcf().autofmt_xdate()

plt.tight_layout()
plt.show()

# %%
pdf_path = '../reports/test_demand_trends_plot.pdf'
plt.figure(figsize=(10, 6))

sns.lineplot(data=df, x='Date', y='Demand')
plt.title('Demand Trends Over Time')

plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gcf().autofmt_xdate()

plt.tight_layout()

plt.savefig(pdf_path, dpi=300)
print(f"Plot saved as {pdf_path}")
# Out:
# Plot saved as ../reports/test_demand_trends_plot.pdf
